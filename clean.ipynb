# %%
import pandas as pd 
df = pd.read_csv('/Users/snehauppu/Documents/Airline_OnTime_Performance/Data/T_ONTIME_REPORTING.csv')
df.head(50000)
# Out:
# /var/folders/_7/g1d8zm1d2mx78py6hrn2xwyr0000gn/T/ipykernel_7057/412821058.py:2: DtypeWarning: Columns (48,77,84) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/Users/snehauppu/Documents/Airline_OnTime_Performance/Data/T_ONTIME_REPORTING.csv')
#        YEAR  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK               FL_DATE  \
# 0      2025        3      9             1            1  9/1/2025 12:00:00 AM
# 1      2025        3      9             1            1  9/1/2025 12:00:00 AM
# 2      2025        3      9             1            1  9/1/2025 12:00:00 AM
# 3      2025        3      9             1            1  9/1/2025 12:00:00 AM
# 4      2025        3      9             1            1  9/1/2025 12:00:00 AM
# ...     ...      ...    ...           ...          ...                   ...
# 49995  2025        3      9             3            3  9/3/2025 12:00:00 AM
# 49996  2025        3      9             3            3  9/3/2025 12:00:00 AM
# 49997  2025        3      9             3            3  9/3/2025 12:00:00 AM
# 49998  2025        3      9             3            3  9/3/2025 12:00:00 AM
# 49999  2025        3      9             3            3  9/3/2025 12:00:00 AM
#
#       OP_UNIQUE_CARRIER  OP_CARRIER_AIRLINE_ID OP_CARRIER TAIL_NUM  ...  \
# 0                    AA                  19805         AA   N101NN  ...
# 1                    AA                  19805         AA   N101NN  ...
# 2                    AA                  19805         AA   N102NN  ...
# 3                    AA                  19805         AA   N102NN  ...
# 4                    AA                  19805         AA   N102NN  ...
# ...                 ...                    ...        ...      ...  ...
# 49995                UA                  19977         UA   N77543  ...
# 49996                UA                  19977         UA   N77543  ...
# 49997                UA                  19977         UA   N77543  ...
# 49998                UA                  19977         UA   N77552  ...
# 49999                UA                  19977         UA   N77552  ...
#
#        DIV4_WHEELS_OFF  DIV4_TAIL_NUM  DIV5_AIRPORT  DIV5_AIRPORT_ID  \
# 0                  NaN            NaN           NaN              NaN
# 1                  NaN            NaN           NaN              NaN
# 2                  NaN            NaN           NaN              NaN
# 3                  NaN            NaN           NaN              NaN
# 4                  NaN            NaN           NaN              NaN
# ...                ...            ...           ...              ...
# 49995              NaN            NaN           NaN              NaN
# 49996              NaN            NaN           NaN              NaN
# 49997              NaN            NaN           NaN              NaN
# 49998              NaN            NaN           NaN              NaN
# 49999              NaN            NaN           NaN              NaN
#
#       DIV5_AIRPORT_SEQ_ID DIV5_WHEELS_ON DIV5_TOTAL_GTIME  DIV5_LONGEST_GTIME  \
# 0                     NaN            NaN              NaN                 NaN
# 1                     NaN            NaN              NaN                 NaN
# 2                     NaN            NaN              NaN                 NaN
# 3                     NaN            NaN              NaN                 NaN
# 4                     NaN            NaN              NaN                 NaN
# ...                   ...            ...              ...                 ...
# 49995                 NaN            NaN              NaN                 NaN
# 49996                 NaN            NaN              NaN                 NaN
# 49997                 NaN            NaN              NaN                 NaN
# 49998                 NaN            NaN              NaN                 NaN
# 49999                 NaN            NaN              NaN                 NaN
#
#       DIV5_WHEELS_OFF  DIV5_TAIL_NUM
# 0                 NaN            NaN
# 1                 NaN            NaN
# 2                 NaN            NaN
# 3                 NaN            NaN
# 4                 NaN            NaN
# ...               ...            ...
# 49995             NaN            NaN
# 49996             NaN            NaN
# 49997             NaN            NaN
# 49998             NaN            NaN
# 49999             NaN            NaN
#
# [50000 rows x 109 columns]

# %%
df.shape
# Out:
# (562439, 109)

# %%
df.columns
# Out:
# Index(['YEAR', 'QUARTER', 'MONTH', 'DAY_OF_MONTH', 'DAY_OF_WEEK', 'FL_DATE',
#        'OP_UNIQUE_CARRIER', 'OP_CARRIER_AIRLINE_ID', 'OP_CARRIER', 'TAIL_NUM',
#        ...
#        'DIV4_WHEELS_OFF', 'DIV4_TAIL_NUM', 'DIV5_AIRPORT', 'DIV5_AIRPORT_ID',
#        'DIV5_AIRPORT_SEQ_ID', 'DIV5_WHEELS_ON', 'DIV5_TOTAL_GTIME',
#        'DIV5_LONGEST_GTIME', 'DIV5_WHEELS_OFF', 'DIV5_TAIL_NUM'],
#       dtype='object', length=109)

# %%
df[['CARRIER_DELAY', 'WEATHER_DELAY', 'NAS_DELAY', 'SECURITY_DELAY', 'LATE_AIRCRAFT_DELAY']].head(20)
# Out:
#     CARRIER_DELAY  WEATHER_DELAY  NAS_DELAY  SECURITY_DELAY  \
# 0             NaN            NaN        NaN             NaN
# 1             NaN            NaN        NaN             NaN
# 2            34.0            0.0        7.0             0.0
# 3             6.0            0.0        0.0             0.0
# 4             NaN            NaN        NaN             NaN
# 5             NaN            NaN        NaN             NaN
# 6             NaN            NaN        NaN             NaN
# 7             NaN            NaN        NaN             NaN
# 8             NaN            NaN        NaN             NaN
# 9             NaN            NaN        NaN             NaN
# 10            NaN            NaN        NaN             NaN
# 11            NaN            NaN        NaN             NaN
# 12            NaN            NaN        NaN             NaN
# 13           51.0            0.0       19.0             0.0
# 14            2.0            0.0        0.0             0.0
# 15            NaN            NaN        NaN             NaN
# 16            NaN            NaN        NaN             NaN
# 17            NaN            NaN        NaN             NaN
# 18            NaN            NaN        NaN             NaN
# 19            NaN            NaN        NaN             NaN
#
#     LATE_AIRCRAFT_DELAY
# 0                   NaN
# 1                   NaN
# 2                   0.0
# 3                  20.0
# 4                   NaN
# 5                   NaN
# 6                   NaN
# 7                   NaN
# 8                   NaN
# 9                   NaN
# 10                  NaN
# 11                  NaN
# 12                  NaN
# 13                309.0
# 14                366.0
# 15                  NaN
# 16                  NaN
# 17                  NaN
# 18                  NaN
# 19                  NaN

# %%
df.isna().sum()
# Out:
# YEAR                       0
# QUARTER                    0
# MONTH                      0
# DAY_OF_MONTH               0
# DAY_OF_WEEK                0
#                        ...
# DIV5_WHEELS_ON        562439
# DIV5_TOTAL_GTIME      562439
# DIV5_LONGEST_GTIME    562439
# DIV5_WHEELS_OFF       562439
# DIV5_TAIL_NUM         562439
# Length: 109, dtype: int64

# %%
df['DIV_AIRPORT_LANDINGS'].value_counts()
# Out:
# DIV_AIRPORT_LANDINGS
# 0.0    561202
# 1.0      1217
# 9.0        12
# 2.0         7
# Name: count, dtype: int64
